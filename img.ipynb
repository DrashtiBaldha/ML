# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('atmiya.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.ones((4,4),np.float32)/16
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x1a99ef894e0>,
#  (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('atmiya.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[-1,-1,-1],[-1,10,-1],[-1,-1,-1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x1a9c8561ea0>,
#  (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('atmiya.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[-1,-1,-1],[-1,7,-1],[-1,0,-1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x1a9bee4d9c0>,
#  (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('atmiya.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[-1,-1,-1],[-1,8,-1],[-1,0,-1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x1a9c0097070>,
#  (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('atmiya.jpg')
plt.imshow(img)

# %%
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
a,b,c=img.shape[:3]
print(a)
print(b)
print(c)
# Out:
# 183
# 275
# 3

# %%
img=cv2.imread('atmiya.jpg')
img=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('nature.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[-1,-1,-1],[-1,7,-1],[-1,0,-1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x1a9c01a5450>,
#  (np.float64(-0.5), np.float64(713.5), np.float64(399.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('nature.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[1,2,1],[1,-10,1],[1,3,1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x1a9cd787ca0>,
#  (np.float64(-0.5), np.float64(713.5), np.float64(399.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('lotus.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[1,2,1],[1,-10,1],[1,2,1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x1a9cda12fb0>,
#  (np.float64(-0.5), np.float64(508.5), np.float64(337.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('lotus.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[1,10,1],[1,10,1],[1,10,1]])
img1=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(img1),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x1a9d40dd2a0>,
#  (np.float64(-0.5), np.float64(508.5), np.float64(337.5), np.float64(-0.5)))
